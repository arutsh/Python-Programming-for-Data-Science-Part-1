# %% [markdown]
# # Matplotlib Basics

# %% [markdown]
# This week we will work with the `matplotlib` library for plotting the results of our data analysis.
# It was designed to be similar to <b>matlab's</b> graphical plotting.
# The reference guide for matplolib can be found here: https://matplotlib.org/stable/plot_types/index.html.
# Helpful examples also here: https://matplotlib.org/stable/gallery/index

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Matplotlib Basics
#
# Let's start by assigning an array of values for the x axes, and for the y axes

# %%
x = np.arange(1, 10, 1)
y = x**2

print(x)
print(y)
# Out:
# [1 2 3 4 5 6 7 8 9]
# [ 1  4  9 16 25 36 49 64 81]

# %% [markdown]
# # There are two different ways to draw plots (lines)

# %% [markdown]
# ## First, the functional appproach:

# %%
# Functional approach 

plt.plot(x, y) 

plt.show()

# %%
# Functional approach 

plt.plot(x, y, 'r')   # r for red - from matlab

plt.xlabel('x axes label')
plt.ylabel('y axes label')
plt.title('Graph') 

plt.show()

# %%
# Functional approach 

plt.subplot(1,2,1)
plt.plot(x, y, 'r')   # r for red - from matlab

plt.subplot(1,2,2)
plt.plot(y, x, 'b')# b for red - from matlab

# %% [markdown]
# # Object-Oriented Approach
#
# - fig / figure is like a blank canvas, that we draw on
# - the axes have to be drawn a little way in from the left and bottom edge - and then stop a little way before the edge of the canvas

# %%
# Object-Oriented Approach

fig = plt.figure() #like a blank canvas

#Now plot the axes on the canvas - draw the lines - 10% in from the left edge 


                    #left, bottom, width, height - in from the edges of the canvas
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])   #takes four arguments

# %%
# Object-Oriented Approach

fig = plt.figure() #like a blank canvas

                    #left, bottom, width, height
axes = fig.add_axes([0.1, 0.1, 1, 1])   #takes four arguments
axes.plot(x,y)
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('The title')
# Out:
# Text(0.5, 1.0, 'The title')

# %% [markdown]
# # Subplots

# %%
fig = plt.figure() #like a blank canvas

# percentages of screen
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])

axes2 = fig.add_axes([0.4,0.4,0.4,0.4])

axes1.plot(x,y)
axes2.plot(y,x)

axes2.set_title('Smaller plot')
axes1.set_title('Larger plot')
# Out:
# Text(0.5, 1.0, 'Larger plot')

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

#axes.plot(x,y)

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 3)

#axes.plot(x,y)

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 3)

#axes.plot(x,y)
plt.tight_layout()

# %% [markdown]
# # Axes is an array of axes

# %%
axes
#axes is an array of axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

for current_ax in axes:
    current_ax.plot(x, y)

# %% [markdown]
# # Invert the axes

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# ## Export figure to png

# %%
fig = plt.figure()

ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)

fig.savefig('mypic.png', dpi=200)

# %% [markdown]
# ## Figure size

# %%
fig = plt.figure(figsize=(2,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig = plt.figure(figsize=(8,8))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %% [markdown]
# # Multiple plots on axes

# %%
fig = plt.figure(figsize=(4,4))

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2)
ax.plot(x,x**3)

# %% [markdown]
# # Using a legend to distinguish between plots

# %%
fig = plt.figure(figsize=(4,4))

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2, label = "X Squared")
ax.plot(x,x**3, label = "X Cubed")

ax.legend() # requires labels to be given to the plots

# %% [markdown]
# # Colo(u)r
# You'll need to use the american 'color' variable here

# %%
fig = plt.figure(figsize=(4,4))

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color = 'red') # have to use american 'color' here

# %% [markdown]
# # Line Width

# %%
fig = plt.figure(figsize=(4,4))

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color = 'red', linewidth = 20) # have to use american 'color' here

# %% [markdown]
# # Alpha for transparency

# %%
fig = plt.figure(figsize=(4,4))

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color = 'red', linewidth = 20, alpha = 0.1) # have to use american 'color' here

# %% [markdown]
# # Linestyle

# %%
fig = plt.figure(figsize=(4,4))

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color = 'red', linewidth = 10, linestyle = '--')

# %% [markdown]
# # Marker

# %%
fig = plt.figure(figsize=(4,4))

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color = 'red', linewidth = 3, linestyle = '-', marker = 'o', markersize = '10')

# %%
fig = plt.figure(figsize=(4,4))

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y, color = 'red', linewidth = 3, linestyle = '-', marker = '1', markersize = '20')

# %% [markdown]
# # Scatter plots

# %%
plt.scatter(x,y)

# %%
"""
Simple demo of a scatter plot.
"""
import numpy as np
import matplotlib.pyplot as plt


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Bar Graphs

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 9., 11.,  7., 10.,  9.,  8.,  9., 13., 11., 13.]),
#  array([  3. , 102.2, 201.4, 300.6, 399.8, 499. , 598.2, 697.4, 796.6,
#         895.8, 995. ]),
#  <BarContainer object of 10 artists>)

# %%
"""
====================
Horizontal bar chart
====================

This example showcases a simple horizontal bar chart.
"""
import matplotlib.pyplot as plt
plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %% [markdown]
# # Box plots

# %%
std = 1
data = [np.random.normal(0,std, 100)]

plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8442f77910>,
#   <matplotlib.lines.Line2D at 0x7f8442f77be0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f8442f77eb0>,
#   <matplotlib.lines.Line2D at 0x7f8442f861c0>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x7f8442f774c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8442f86490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8442f86760>],
#  'means': []}

# %%
data = [np.random.normal(0,std, 100) for std in range(1,4)]

plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f84213a4460>,
#   <matplotlib.lines.Line2D at 0x7f84213a4730>,
#   <matplotlib.lines.Line2D at 0x7f84614287c0>,
#   <matplotlib.lines.Line2D at 0x7f8461428a90>,
#   <matplotlib.lines.Line2D at 0x7f8461434b20>,
#   <matplotlib.lines.Line2D at 0x7f8461434df0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f84213a4a00>,
#   <matplotlib.lines.Line2D at 0x7f84213a4cd0>,
#   <matplotlib.lines.Line2D at 0x7f8461428d60>,
#   <matplotlib.lines.Line2D at 0x7f8461434070>,
#   <matplotlib.lines.Line2D at 0x7f8461441100>,
#   <matplotlib.lines.Line2D at 0x7f84614413d0>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x7f84213a40a0>,
#   <matplotlib.patches.PathPatch at 0x7f8461428370>,
#   <matplotlib.patches.PathPatch at 0x7f84614346d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f84213a4fa0>,
#   <matplotlib.lines.Line2D at 0x7f8461434340>,
#   <matplotlib.lines.Line2D at 0x7f84614416a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f84614282b0>,
#   <matplotlib.lines.Line2D at 0x7f8461434610>,
#   <matplotlib.lines.Line2D at 0x7f8461441970>],
#  'means': []}

# %% [markdown]
# # Bar for Bar Graph

# %% [markdown]
# # Exploratory data analysis

# %%
import matplotlib.pyplot as plt
import numpy as np

N = 4

survived = (70, 80, 20, 300 )
perished = (20, 30, 319, 100)


ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

p1 = ax.bar(ind, survived, width, label='Survived')

p2 = ax.bar(ind, perished, width,
            bottom=survived, label='Perished')

ax.axhline(0, color='grey', linewidth=1)
ax.set_ylabel('Count')
ax.set_title('Survival by group and gender')

ax.set_xticks(ind, labels=['Boys', 'Girls', 'Men', 'Women'])
ax.legend()

# Label with label_type 'center' instead of the default 'edge'
ax.bar_label(p1, label_type='center')
ax.bar_label(p2, label_type='center')
ax.bar_label(p2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(3)

x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))



plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make the data
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, len(x))

# size and color:
sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

# plot
fig, ax = plt.subplots()

ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)


ax.set(xlim=(0, 8), xticks = np.arange(1,8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
data = [1,2,3,4]
labels = ['USA', 'China', 'Sweden', 'UK']

series2 = pd.Series(data, labels)
series2
# Out:
# USA       1
# China     2
# Sweden    3
# UK        4
# dtype: int64

# %% [markdown]
# # DataFrames (+ Random number generation)
#
# First let's generate some random numbers via the random module in numpy
#
# Repeatedly run the cell below - what do you notice?

# %%
from random import randint
import numpy as np
import pandas as pd

from numpy.random import randn

np.random.seed(2000)

rnum = randint(1,100)
rarr = randn(5,4)

print(rnum)
print(rarr)
# Out:
# 26
# [[ 1.73673761  1.89791391 -2.10677342 -0.14891209]
#  [ 0.58306155 -2.25923303  0.13723954 -0.70121322]
#  [-0.62078008 -0.47961976  1.20973877 -1.07518386]
#  [ 0.80691921 -0.29078347 -0.22094764 -0.16915604]
#  [ 1.10083444  0.08251052 -0.00437558 -1.72255825]]
